# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)
#
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [  ] YES - make available
# * [ X ] NO - keep private
#
# # Names
#
# - Dean Nafarrete
# - Emily Le
# - Cedric Jeng
# - Kevin Morales
# - Richard Lao
#
# ### Project Presentation Video:
# https://youtu.be/dLSvBZRSmlo
#
# # Abstract
#
# This project explores how environmental degradation and economic factors relate to crime rates in California, with the goal of developing a more holistic model of economic health. While our statistical analysis revealed limited significant relationships between individual variables and crime, notable patterns emerged; particularly the correlation between air quality and property crime, and between unemployment and crime rates. These align with prior research and support our initial hypotheses about the role of quality-of-life factors in shaping criminal behavior. To address the limitations of GDP as a sole measure of prosperity, we introduced the Quality of Life and Economy Indicator (QLEI), a value-driven index designed to weigh both economic output and societal well-being. Compared to a baseline PCA model, QLEI revealed key disparities, especially in urban counties where GDP alone overstated economic health. Though rural patterns were more homogeneous, our findings suggest that data-informed indices like QLEI offer a unique alterative for economic health; one that accounts not just for economic output, but the human and environmental context it operates within.

# %% [markdown]
# # Research Question

# %% [markdown]
# Is there a statistically significant relationship between a region's economic health(GDP and Household Income), environmental degradation(Greenhouse Gas Emissions and Air Quality), and unemployment rate on crime rates? How can we use these variables to create a new standard measurement for economic health?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# <span style = "font-family: 'Segoe UI'; font-size: 17px;">
# 	<p>Since the advent of the modern industrial city, crime rates in urban areas have been a consistent concern. By nature, cities are densely populated with a robust infrastructure and diverse economy, and tend to attract more people. With such a large population in a small area, it’s inevitable that crime will rise proportionally; however, underlying factors beyond industrialization are at play in these statistics. Many hold the sentiment that cities are less ideal places to settle due to factors like crime rate, population density, and homelessness while praising the large economies that seemingly contribute to these issues. Ultimately, cities have become an integral part of the globalized economy, serving as centers for trade and culture despite the negative connotations. Consequently, efforts to remedy these issues by identifying and addressing the root causes tend to go overlooked or rarely implemented. Economic health and overall quality of life are not mutually exclusive as many seem to believe. An in-depth analysis of the effects of the physical and social environment may provide insight into issues that require more allocation to reduce crime rates in the future. In studying these factors, establishing a new measure for economic health that is inclusive of issues that impact those living within cities can deviate focus away from simple measures like GDP, which only measure the gross economic output of a given region, and allow for more nuanced discussions on how to maximize economic returns while reducing the toll on average citizens.<p>
# 	<p>The disproportionate amount of crime in urban areas is a topic that has been heavily explored by sociologists and economists alike. An article from the Journal of Political Economy, “Why is There More Crime in Cities?”,  compiled a number of different theories. They note that crime rates in cities outpace their rural counterparts even when accounting for the larger population. Some of the theories they posit suggest that dense city environments may cultivate less connected communities compared to smaller towns, decrease risk for criminals, or that those looking to profit from crime are likely to find it in economic centers. Ultimately, they found that crime reporting is underrepresented in cities, and the likelihood of arrest for a given crime is lower.<a name="#cite_note-1">[1]</a> Regardless, it’s difficult to pinpoint any one cause, and the theories are merely speculation on the social implications on crime. As for the environment, much less research is evident. The council on Strategic Risks highlighted this issue; extreme weather events, higher temperatures, and social factors related to stresses based on climate have been linked to various forms of crime, especially violent crime. Some examples include gender-based violence against women increasing following adverse weather events and the likelihood of mass shooting events increasing in the summer months. The working theory is that changes in the environment may indirectly cause stresses that incentivize crime more by reducing the perceived risk for potential criminals.<a name="#cite_note-2">[2]</a> Directly connecting a factor of climate change, like environmental degradation, may lend more credence to this issue being a factor in addressing crime in the future.<p>
# 	<p>Along with changes in the climate, income inequality is a known factor in crime rates. Increasing fears over crime often go hand in hand with homelessness; as such, this phenomenon has been explored in the past. The Institute of Labor Economics studied this effect in California, finding that homeless rates and crime rates are linked, but how they are linked is interesting; high rates of homelessness increase the number of violent crimes, but not property crimes.<a name="cite_note-3">[3]</a> Given this study was conducted at the state level, perhaps focusing on a single area may reaffirm or contradict this finding, depending on how a smaller, less diversified economy may have an effect. On the whole, while larger factors on crime rates appear to go overlooked, there have been some initiatives to address this disparity between economy, climate, inequality, and crime. Several states have implemented an alternate measure of economic health known as the genuine progress indicator, or GPI. This standard allows states to take into consideration non-economic factors like the environment and human health standards on the economy. According to the government of Maryland, this measure informs policymakers of economic progress without purely looking at the economic output, which may increase at the expense of its citizens.<a name="cite_note-4">[4]</a> We believe that this approach is more progressive on these issues and may prove to benefit the economy and well being of individuals in unison, however, the fact that this model is only implemented in a few states as a policy informing measurement is insufficient. Finding a general link between these factors may reveal the true cost of these factors, and potentially allow us to devise another measurement that can be achieved using public data.<p>
#   </span>
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Glaeser, E. L., & Sacerdote, B. (1999). Why is There More Crime in Cities? Journal of Political Economy, 107(S6), S225–S258. https://doi.org/10.1086/250109
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Facini, A. (2024, October 17). Climate Change & Crime: A big, bad, largely overlooked Nexus. The Council on Strategic Risks. http://councilonstrategicrisks.org/2024/10/17/climate-change-crime-a-big-bad-largely-overlooked-nexus/
# 3. <a name="cite_note-3"></a> [^](cite_ref-3) Artz, B., & Welsch, D. M. (2024, June). Homelessness and crime: An examination of California. Institute of Labor Economics. https://docs.iza.org/dp17086.pdf
# 4. <a name="cite_note-4"></a> [^](cite_ref-4) Campbell, E. (n.d.). Maryland Genuine Progress Indicator. Maryland Department of Natural Resources. https://dnr.maryland.gov/mdgpi/Pages/default.aspx

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Our hypothesis is that there is a significant relationship with environmental degradation, high economic output, and unemployment that affects crime rates, and using these factors we can create a new measure of a city’s well being as an alternate measure of economic health. In order to measure these variables, we are looking at the air quality index, greenhouse gas index, unemployment percentage rates, and crime rates for each county. Higher outputs of the economy attract higher rates of crime because of the high foot traffic in retail centers where businesses sell products and people are carrying valuables or money. Furthermore, the stress of falling into unemployment and being homeless have individuals resorting to committing crimes as one of their survival options. As the environment continues to decline, this will also be another factor that leads to higher crime rates and in particular violent crimes due to lower air quality and greenhouse gases creating a toxic environment, thus inflicting environmental stress on the population. All of these variables are high stressing factors in people’s lives, which ultimately dictate their wellbeing, safety, and future hence why when these variables are threatened in their lives, people will turn towards committing crimes in order to ensure their survival. Additionally, we believe that there will be a noticeably greater significant effect on crime rates of our given variables in urbanized areas compared to its rural counterparts.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# * Our ideal dataset would be a dataset that includes measures for a region's GDP, median household income, unemployment, carbon emissions, air quality, solid waste, and crime rates. Our ideal number of observations include our variables from all counties in California across multiple years with the ideal span being about 10 years. This would look like about 58 counties with a 10 year span per county. Looking at the data we have already found our time span can vary, but there is a time period where all our datasets line up.
#
# * <u>**Environmental degradation**</u> data: Green house Gas Emissions :https://www.epa.gov/system/files/other-files/2024-10/2023_data_summary_spreadsheets.zip ; Air Quality: https://www.epa.gov/outdoor-air-quality-data/air-quality-statistics-report<br>
#
# * **San Diego Median Income/Capita, Crime Rates, Unemployment info, based on specific regions in San Diego** <br>
# https://data.sandiegocounty.gov/Live-Well-San-Diego/Live-Well-/San-Diego-Database/wsyp-5xpf/about_data <br>
#
# * <u>**Unemployment.. Less than Ideal**</u> <br>
# Unemployment rate for California (as a whole):  https://labormarketinfo.edd.ca.gov/geography/california-statewide.html <br>
# Unemployment rate for California (as counties): https://labormarketinfo.edd.ca.gov/geography/lmi-by-county.html <br>
# * <u>Crime</u> <br>
# Crime rates broken down into total crime, violent crime, and property crime rates for cities/regions in San Diego county: https://data.sandiegocounty.gov/Safety/SANDAG-Crime-Data/486f-q228/data_preview <br>
#
#
# * All these sites have data that's not only obtainable but also easily processes because they are kept in Excel files. Excel files are csv files which can be easily turned into pandas dataframes. Of course, these sites contain more data than we need in our project, so tidying will be necessary. Moreover, we may choose a focus on specific types of crimes, such as violent crimes versus misdemeanors, or we may choose to look at all crime as a whole.
#
# <u>Environmental Datasets</u>
# - Dataset #1
#   - Dataset Name: Air Quality Dataset
#   - Link to the dataset: https://www.epa.gov/outdoor-air-quality-data/air-quality-statistics-report
#   - Number of observations: 823
#   - Number of variables: 18
#   - Description: This dataset tracks county-level air quality metrics across California from 2010-2025, with each row representing a county's annual aggregate data. The key variables include AQI metrics (AQI Maximum, AQI 90th Percentile, and AQI Median), which serve as proxies for understanding the air quality in a respective county in a specific year and as baseline air quality respectively. The data requires cleaning to handle columns of information not needed in this project as well as standardizing labels to fit with our other datasets. We will use `.strip()` for removing empty spaces, `.split()` for removing redundant words, `.rename()` to clean up labels and prepare for `.merge()`.
# - Dataset #2
#   - Dataset Name: Average Temperature by County, California
#   - Link to the datasets:
#   - Number of observations: 12199
#   - Number of variables: 2
#   - Description: This dataset contains the average temperature from 2000-2025 based on month, which we will average out over each year and compare against crime rates to see if higher temperatures are correlated with crime rate.
# - Dataset #3
#   - Dataset name : Greenhouse Gas Emissions
#   - Link to the dataset: https://www.epa.gov/system/files/other-files/2024-10/2023_data_summary_spreadsheets.zip
#   - Number of Observations:767
#   - Number of Variables:3
#   - Description: We plan to use the the Green House Gas Emissions data set to look at emissions of green house gases per county, measured in units of metric tons of carbon dioxide. We plan on using **.dropna()** in order to get rid of missing data entries as well as using **.melt()** to reshape the data into long format and **.apply()** to further wrangle the dataset in order to remove the redundancy of county in the original unwrangled and tidy dataset . Further more the key observations for this datasets will be looking at the emmisions by county in CA overtime in order to compare against the other datasets in the project.
#
# <u>Economy Datasets</u>
# - Dataset #4
#   - Dataset Name: Real Total GDP by County, California
#   - Link to the datasets: https://fredaccount.stlouisfed.org/public/datalist/8338
#   - Number of observations: 1357
#   - Number of variables: 2
#   - Description: We plan to use Real Total GDP for all the counties in California to compare against crime data, measured in thousands of chained 2017 USD. This dataset measures the GDP of all industries for their respective county and adjusts it for inflation, offering a true measure of economic growth that can be compared against crime data. Since the data is based on observation dates measured at the beginning of each year, we plan to change each observation date to account for the previous year's data and drop any missing data entries.
# - Dataset #5
#   - Dataset Name: Median Household Income by County, California
#   - Link to the datasets: https://fred.stlouisfed.org/searchresults/?st=median%20household%20income%20county%20california
#   - Number of observations: 1357
#   - Number of variables: 2
#   - Description: We plan to use Median Household Income to compare against crime data, measured in USD, to determine whether the economic status of individuals has an effect on crime rate. This dataset measures the median household income for all counties in California. Since the data is based on observation dates measured at the beginning of each year, we plan to change each observation date to account for the previous year's data and drop any missing data entries.
# - Dataset #6
#   - Dataset Name: Unemployment Rates by County, California
#   - Link to the datasets: https://fredaccount.stlouisfed.org/public/datalist/8337
#   - Number of observations: 1478
#   - Number of variables: 2
#   - Description: The dataset contains the unemployment percentage rates of each county within California each year from the year 2000 to 2024 to compare against crime rates in each given year. Since the data is based on observation dates measured at the beginning of each year, we plan to change each observation date to account for the previous year's data and drop any missing data entries.
#
# <u>Crime</u>
# - Dataset #7
#   - Dataset Name: Crime Rate Dataset
#   - Link to the datasets:
#   - https://dof.ca.gov/forecasting/demographics/estimates/ (for population)
#   - https://openjustice.doj.ca.gov/data (for crime count)
#   - Number of observations: 28591 (for crime), 1770 (for population)
#   - Number of variables: 70 (for crime), 3 (for population)
#   - Description: We plan to look at **Violent_sum**, **Property_sum** within the crime count dataset & **Population** within the population dataset. For both, we will look at **Year** and **County**. Both datasets contain datetime datatype for **Year**, integer datatype for **Violent_sum**, **Property_sum**, & **Population**, and string datatype for **County**, but can contain undefined values which we replace with **0** instead.
#   - We plan to use `.strip()` for removing empty spaces, `pd.to_datetime()` for converting **Year** to an integer datatype, `.split()` for removing redundant words like '*County*' in 'Alameda *County*', `.astype()` to explicity convert our data to integer, `.melt()` to reshape the population dataframe to a long format, `.drop()` for unecessary columns, `.rename()` for making consistent columns before merge, and `.merge()` to get the complete Crime Rate Dataset. Both datasets will be merged from 2000-2025, where crime rate will then be calculated directly using the population count per county and crime commited per county. This will be the rate of crime per 100,000 residents, which will be used as a proxy for how social and economic well-being.
#
# <u>Extra</u>
# - Dataset #8:
#   - Dataset Name: Top 10 Rural/Urban Counties
#   - Link to dataset: https://www.ers.usda.gov/data-products/rural-urban-continuum-codes, https://bythenumbers.sco.ca.gov/Finance-Application/County-Expenditures/uctr-c2j8/about_data
#   - Number of observations: 416898, 3235
#   - Number of variables: 13, 6
#   - Description: We will filter out the top 10 rural counties and the top 10 urban counties through this dataset. This will be done by population density by Sq. Mile, which we can further validate by referencing it with the dataset provided by the Economic Research Service U.S. DEPARTMENT OF AGRICULTURE that further takes into account adjacency of counties to other metro counties. We will use this dataset for selecting the counties that we will use in upcoming EDA.

# %%
# import necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os 
import requests
from io import StringIO
import statsmodels.formula.api as smf 
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA

# %% [markdown]
# ## <u> Environmental Datasets </u>

# %% [markdown]
# ## Air Quality Dataset

# %%
aq_df = pd.DataFrame()

# Load Air Quality Datasets + Add Year Column
for filename in os.listdir('./Datasets/AirQuality/'): 
    file_path = os.path.join('./Datasets/AirQuality/', filename)
    if '.csv' not in file_path: 
        continue
    year_val = int(filename.strip('aqireport.csv'))
    df_temp = pd.read_csv(file_path)
    df_temp = df_temp.assign(Year=year_val)
    aq_df = pd.concat([aq_df, df_temp])

# Removed Redundant Naming
county_name = aq_df.get('County').str.split().str[:-2]
county_name = county_name.apply(' '.join)
aq_df['County'] = county_name
aq_df.sort_values(by=['Year', 'County'], inplace=True)

# Dropped Unnecessary Columns
aq_df = aq_df[['County', 'AQI Maximum', 'AQI 90th Percentile', 'AQI Median', 'Year']]
aq_df
# Out:
#         County  AQI Maximum  AQI 90th Percentile  AQI Median  Year
# 0      Alameda          179                 72.0        52.0  2010
# 1       Amador          151                 64.0        35.0  2010
# 2        Butte          126                 84.0        53.0  2010
# 3    Calaveras          154                 84.0        44.0  2010
# 4       Colusa          119                 54.0        39.0  2010
# ..         ...          ...                  ...         ...   ...
# 20      Solano           16                 15.0         5.5  2025
# 21  Stanislaus           87                 85.0        37.0  2025
# 22      Tulare          104                 57.0        34.0  2025
# 23     Ventura          125                 54.0        43.5  2025
# 24        Yolo           26                 24.0        10.0  2025
#
# [823 rows x 5 columns]

# %% [markdown]
# ## Temperature Dataset

# %%
temp_env = pd.DataFrame()
#load all county datasets, merge into one dataset

for filename in os.listdir('./Datasets/Temperature/'): 
    file_path = os.path.join('./Datasets/Temperature/', filename)
    if '.csv' not in file_path: 
        continue
    county_temp = filename.replace(' County.csv', '').upper()
    df_temp = pd.read_csv(file_path, comment='#')
    df_temp = df_temp.assign(County=county_temp)
    temp_env = pd.concat([temp_env, df_temp])

#cleanup
temp_env = temp_env.rename(columns={'Value':'Average Temperature'})
temp_env['Year'] = temp_env['Date'].astype(str).str[:4].astype(int)
temp_env = temp_env.drop(columns='Date')
temp_env = temp_env.groupby(['County', 'Year']).mean().reset_index()

temp_env.head()
# Out:
#     County  Year  Average Temperature
# 0  ALAMEDA  2000            59.275000
# 1  ALAMEDA  2001            58.891667
# 2  ALAMEDA  2002            59.175000
# 3  ALAMEDA  2003            59.600000
# 4  ALAMEDA  2004            59.758333

# %% [markdown]
# ## Greenhouse Gas Emissions Dataset

# %%
# loading data into a df 
Ge_df = pd.read_excel('./Datasets/ghgp_data_by_year_2023.xlsx', skiprows=3)

# filtering th df to contain only rows relevant to California
Ge_df = Ge_df[Ge_df['State']=='CA']
Ge_df = Ge_df.dropna()

Ge_df['County'] = Ge_df['County'].str.upper()
# removing redundancy of 'County ' in each county name as it will become its own column
Ge_df['County'] = Ge_df['County'].apply(lambda x: x.replace('COUNTY','') if 'COUNTY' in x else x)
year = 2023
for col in Ge_df.columns:
    if col.startswith('20'):
        Ge_df.rename(columns = {col :f'{year}'}, inplace=True)
        year = year-1
Ge_df = Ge_df[['County','2023','2022','2021','2020','2019','2018','2017','2016','2015','2014','2013','2012','2011']]
Ge_df.head()

Ge_df = pd.melt(Ge_df, id_vars= ['County',], var_name='Year', value_name = 'emmisions')
Ge_df = Ge_df.groupby(['County','Year',], as_index =False).sum()
#wrangled and tidy data set based of year, county and emmisions
Ge_df.head(20)
# Out:
#       County  Year      emmisions
# 0   ALAMEDA   2011  388736.749724
# 1   ALAMEDA   2012  376022.924941
# 2   ALAMEDA   2013  283117.164000
# 3   ALAMEDA   2014  276578.428000
# 4   ALAMEDA   2015  287181.554000
# 5   ALAMEDA   2016  260019.676000
# 6   ALAMEDA   2017  253033.534000
# 7   ALAMEDA   2018  229303.738000
# 8   ALAMEDA   2019  260290.764000
# 9   ALAMEDA   2020  246664.376000
# 10  ALAMEDA   2021  241217.116000
# 11  ALAMEDA   2022  247921.530000
# 12  ALAMEDA   2023  293631.040000
# 13    BUTTE   2011   69572.170000
# 14    BUTTE   2012   53313.614000
# 15    BUTTE   2013   52691.000000
# 16    BUTTE   2014   56373.648000
# 17    BUTTE   2015   31571.006000
# 18    BUTTE   2016   26796.864000
# 19    BUTTE   2017   31524.698000

# %% [markdown]
# ## <u> Economic Datasets </u>

# %% [markdown]
# ## GDP Dataset

# %%
# pre-EDA prep 
# loading the url gto bypass ssl certification 
url = 'https://raw.githubusercontent.com/kjhealy/fips-codes/master/state_and_county_fips_master.csv'
response = requests.get(url, verify = False)
fips_csv  = StringIO(response.text)


#load gdp dataset, convert columns to county fip code

realgdp_ca = pd.read_csv('./Datasets/GDP & Income Data/gdp-by-county-ca2.csv')
realgdp_ca.columns = [int(col.replace('REALGDPALL', '')) if col.startswith('REALGDPALL') else col for col in realgdp_ca.columns]

#load list of fip codes, replace fip codes in gdp dataset with county names
fips_df = pd.read_csv(fips_csv)
fips_ca = fips_df[fips_df['state'] == 'CA']
fips_county = dict(zip(fips_ca['fips'], fips_ca['name']))
realgdp_ca.rename(columns=fips_county, inplace=True)

#units (Thousands of Chained 2017 USD, Not Seasonally Adjusted)
realgdp_ca.attrs['units'] = 'Thousands of Chained 2017 USD'

# pre-EDA prep
# wrangling dataset further to get year and county in their specific colums
realgdp_ca.rename(columns= {'observation_date': 'Year'}, inplace = True)
realgdp_ca['Year'] = realgdp_ca.get('Year').apply(pd.to_datetime).dt.year
realgdp_ca = pd.melt(realgdp_ca, id_vars= ['Year',], var_name='County', value_name = 'gdp_adjusted')
#capatilizing Data in coulmn series to be consistent with Current DF's
realgdp_ca['County'] = realgdp_ca['County'].str.upper()

# removing redundancy of county in county value for each row 
realgdp_ca['County'] = realgdp_ca['County'].apply(lambda x: x.replace('COUNTY','') if 'COUNTY' in x else x)

realgdp_ca.head()
# Out:
# c:\Users\cjjen\code\COGS108\Projects\Group131_SP25\venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'raw.githubusercontent.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
#    Year    County  gdp_adjusted
# 0  2001  ALAMEDA       86924126
# 1  2002  ALAMEDA       87945920
# 2  2003  ALAMEDA       91564585
# 3  2004  ALAMEDA       92470454
# 4  2005  ALAMEDA       94611477

# %% [markdown]
# ## Median Income Dataset

# %%
#load median income dataset, convert columns to county fip code
medianinc_ca = pd.read_csv('./Datasets/GDP & Income Data/median-income-county-ca.csv')
medianinc_ca.columns = [col.replace('A052NCEN', '') if col.startswith('MHICA') else col for col in medianinc_ca.columns]
medianinc_ca.columns = [int(col.replace('MHICA', '')) if col.startswith('MHICA') else col for col in medianinc_ca.columns]

#replace fip codes in median income dataset with county names
medianinc_ca.rename(columns=fips_county, inplace=True)

#units (USD, Not Seasonally Adjusted)
medianinc_ca.attrs['units'] = 'USD, Unadjusted for inflation'

medianinc_ca

#pre-EDA prep
# wrangling dataset further to get year and county in their specific colums
medianinc_ca.rename(columns= {'observation_date': 'Year'}, inplace = True)
# getting specific year from a date

medianinc_ca['Year'] = medianinc_ca.get('Year').apply(pd.to_datetime).dt.year
# melting data to get county names in one column along with income
medianinc_ca = pd.melt(medianinc_ca, id_vars= ['Year',], var_name='County', value_name = 'income')
#capatilizing Data in coulmn series to be consistent with Current DF's
medianinc_ca['County'] = medianinc_ca['County'].str.upper()

# removing redundancy of county in county value for each row 
medianinc_ca['County'] = medianinc_ca['County'].apply(lambda x: x.replace('COUNTY','') if 'COUNTY' in x else x)

medianinc_ca.head()
# Out:
#    Year    County  income
# 0  2001  ALAMEDA    54925
# 1  2002  ALAMEDA    55595
# 2  2003  ALAMEDA    56225
# 3  2004  ALAMEDA    57659
# 4  2005  ALAMEDA    60937

# %% [markdown]
# ## Unemployment Rate Dataset

# %%
unemploymentrate = pd.read_csv('./Datasets/Unemployment/Unemployment_by_counties.csv')
unemploymentrate.head()

# pre-EDA prep

# further wrangling unemployment dataset

# wrangling dataset further to get year and county in their specific colums
unemploymentrate.rename(columns= {'observation_date': 'Year'}, inplace = True)
# getting specific year from a date

unemploymentrate['Year'] = unemploymentrate.get('Year').apply(pd.to_datetime).dt.year
# melting data to get county names in one column along with income
unemploymentrate = pd.melt(unemploymentrate, id_vars= ['Year',], var_name='County', value_name = 'unemployment_rate')
#capatilizing Data in coulmn series to be consistent with Current DF's  
unemploymentrate['County'] = unemploymentrate['County'].str.upper()

# removing redundancy of county in county value for each row 
unemploymentrate['County'] = unemploymentrate['County'].apply(lambda x: x.replace('COUNTY','') if 'COUNTY' in x else x)

unemploymentrate.head(20)
# Out:
#     Year    County  unemployment_rate
# 0   2000  ALAMEDA                 3.6
# 1   2001  ALAMEDA                 4.8
# 2   2002  ALAMEDA                 6.8
# 3   2003  ALAMEDA                 6.9
# 4   2004  ALAMEDA                 5.9
# 5   2005  ALAMEDA                 5.1
# 6   2006  ALAMEDA                 4.4
# 7   2007  ALAMEDA                 4.7
# 8   2008  ALAMEDA                 6.2
# 9   2009  ALAMEDA                10.6
# 10  2010  ALAMEDA                11.0
# 11  2011  ALAMEDA                10.1
# 12  2012  ALAMEDA                 8.7
# 13  2013  ALAMEDA                 7.3
# 14  2014  ALAMEDA                 5.9
# 15  2015  ALAMEDA                 4.8
# 16  2016  ALAMEDA                 4.1
# 17  2017  ALAMEDA                 3.5
# 18  2018  ALAMEDA                 2.9
# 19  2019  ALAMEDA                 2.8

# %% [markdown]
# ## <u> Crime Datasets </u>

# %%
# Loading number of crime data
# Cleaning up data
crime_num_df = pd.read_csv(
    './Datasets/Crime/Crimes_and_Clearances_with_arson-1985-2023.csv', 
    dtype=object)
crime_num_df = crime_num_df.drop(columns='NCICCode')
crime_num_df.replace(' ', 0, inplace=True)
crime_num_df.replace(np.nan, 0, inplace=True)
for col in crime_num_df.columns: 
    if(col == 'County' or col == 'NCICCode'): 
        continue 
    crime_num_df[col] = crime_num_df[col].astype(int)
crime_num_df = crime_num_df[['Year', 'County', 'Violent_sum', 'Property_sum']].groupby(['Year', 'County']).sum()
crime_num_df = crime_num_df.reset_index()
#Filter to start from 2001
crime_num_df = crime_num_df[crime_num_df['Year'] >= 2000]

# Removing 'County'
crime_num_df['Year'] = crime_num_df['Year'].astype(object)
name = crime_num_df.get('County').str.split().str[:-1]
crime_num_df['County'] = name.apply(' '.join)

crime_num_df
# Out:
#       Year     County  Violent_sum  Property_sum
# 870   2000    Alameda         9485         58334
# 871   2000     Alpine           10            77
# 872   2000     Amador          179           674
# 873   2000      Butte          699          6514
# 874   2000  Calaveras          118           914
# ...    ...        ...          ...           ...
# 2257  2023     Tulare         2481          9535
# 2258  2023   Tuolumne          369           522
# 2259  2023    Ventura         2411         11071
# 2260  2023       Yolo          561          4968
# 2261  2023       Yuba          334           828
#
# [1392 rows x 4 columns]

# %%
# Load Population Data for 2000-2010
p1_df = pd.read_excel(
    './Datasets/Census/E4_2000-2010_Report_Final_EOC_000.xlsx',
    sheet_name=1,skiprows=3)
p1_df.dropna(how='all', inplace=True)
p1_df = pd.melt(
    p1_df, id_vars='COUNTY',
    var_name='Year', 
    value_name='Population')
p1_df['COUNTY'] = p1_df.get('COUNTY').str.strip()

# Load Population Data for 2010-2020
p2_df = pd.read_excel(
    './Datasets/Census/E-4_2010-2020-Internet-Version.xlsx',
    sheet_name=1, skiprows=1)
p2_df.drop(columns=['Column1', 'Column2'], inplace=True)
p2_df = pd.melt(p2_df, id_vars='COUNTY', var_name='Year',
    value_name='Population')
p2_df.dropna(how='all', inplace=True)
p2_df['COUNTY'] = p2_df.get('COUNTY').str.strip()
p2_df.get('Year').apply(pd.to_datetime)

# Load Population Data 2020-2025
p3_df = pd.read_excel(
    './Datasets/Census/E-4_2025_InternetVersion.xlsx',
    sheet_name=1, skiprows=2)
p3_df = p3_df.iloc[0:59]
p3_df = pd.melt(p3_df, id_vars='County', var_name='Year',
    value_name='Population')
p3_df['County'] = p3_df.get('County').str.strip()
p3_df = p3_df.rename(columns={'County': "COUNTY"})
p3_df

# Merge Population Data From 2000-2025 + Clean Up Data
pop_df = pd.concat([p1_df, p2_df, p3_df])
pop_df['Year'] = pop_df.get('Year').apply(pd.to_datetime).dt.year
pop_df.rename(columns={'COUNTY':'County'}, inplace=True)
pop_df['Year'] = pop_df['Year'].astype(object)
pop_df
# Out:
#           County  Year  Population
# 0        Alameda  2000   1443939.0
# 1         Alpine  2000      1208.0
# 2         Amador  2000     35100.0
# 3          Butte  2000    203171.0
# 4      Calaveras  2000     40554.0
# ..           ...   ...         ...
# 349     Tuolumne  2025     54357.0
# 350      Ventura  2025    829005.0
# 351         Yolo  2025    225433.0
# 352         Yuba  2025     85023.0
# 353  State Total  2025  39529101.0
#
# [1770 rows x 3 columns]

# %%
# Merge Population Dataset With Crime Number Dataset
crime_rate_df = pop_df.merge(crime_num_df, on=['Year', 'County'])

# Calculate crime rate percentages
crime_rate_df['Violent_rate'] = (crime_rate_df['Violent_sum'])/(crime_rate_df['Population'])
crime_rate_df['Property_rate'] = (crime_rate_df['Property_sum'])/(crime_rate_df['Population'])

# Multiply to get rate of crime per 100,000 residents 
crime_rate_df['Violent_rate'] = (crime_rate_df['Violent_rate'] * 100000).apply(round)
crime_rate_df['Property_rate'] = (crime_rate_df['Property_rate'] * 100000).apply(round)


crime_rate_df.head()
# Out:
#       County  Year Population  Violent_sum  Property_sum  Violent_rate  \
# 0    Alameda  2000  1443939.0         9485         58334           657
# 1     Alpine  2000     1208.0           10            77           828
# 2     Amador  2000    35100.0          179           674           510
# 3      Butte  2000   203171.0          699          6514           344
# 4  Calaveras  2000    40554.0          118           914           291
#
#    Property_rate
# 0           4040
# 1           6374
# 2           1920
# 3           3206
# 4           2254

# %%
# Loading number of crime data
# Cleaning up data
crime_num_df = pd.read_csv(
    './Datasets/Crime/Crimes_and_Clearances_with_arson-1985-2023.csv', 
    dtype=object)
crime_num_df = crime_num_df.drop(columns='NCICCode')
crime_num_df.replace(' ', 0, inplace=True)
crime_num_df.replace(np.nan, 0, inplace=True)
for col in crime_num_df.columns: 
    if(col == 'County' or col == 'NCICCode'): 
        continue 
    crime_num_df[col] = crime_num_df[col].astype(int)
crime_num_df = crime_num_df[['Year', 'County', 'Violent_sum', 'Property_sum']].groupby(['Year', 'County']).sum()
crime_num_df = crime_num_df.reset_index()
#Filter to start from 2001
crime_num_df = crime_num_df[crime_num_df['Year'] >= 2000]

# Removing 'County'
crime_num_df['Year'] = crime_num_df['Year'].astype(object)
name = crime_num_df.get('County').str.split().str[:-1]
crime_num_df['County'] = name.apply(' '.join)

crime_num_df
# Out:
#       Year     County  Violent_sum  Property_sum
# 870   2000    Alameda         9485         58334
# 871   2000     Alpine           10            77
# 872   2000     Amador          179           674
# 873   2000      Butte          699          6514
# 874   2000  Calaveras          118           914
# ...    ...        ...          ...           ...
# 2257  2023     Tulare         2481          9535
# 2258  2023   Tuolumne          369           522
# 2259  2023    Ventura         2411         11071
# 2260  2023       Yolo          561          4968
# 2261  2023       Yuba          334           828
#
# [1392 rows x 4 columns]

# %% [markdown]
# ## <u> Extra Datasets </u>

# %% [markdown]
# ## Top Ten Rural/Urban Counties

# %%
# Load Rural and Urban Codes Dataset
rural_urban_df = pd.read_excel('./Datasets/Rural_Urban_Codes/Ruralurbancontinuumcodes2023.xlsx')
rural_urban_df = rural_urban_df[rural_urban_df.get('State') == 'CA']
rural_urban_df = rural_urban_df[['County_Name', 'Population_2020', 'Description']]

# Tidy County Naming
rural_urban_df.columns = ['County', 'Population', 'Description']
name = rural_urban_df.get('County').str.split().str[:-1]
rural_urban_df['County'] = name.apply(' '.join)

# Load Geography Data, Area Sq. Miles for Each County
metro = pd.read_csv('./Datasets/Expenditures/County_-_Expenditures_20250513.csv')
metro = metro[['Entity Name', 'Area in Sq. Miles', 'Fiscal Year']].groupby(['Entity Name', 'Fiscal Year']).mean().reset_index()
metro.columns = ['County', 'Year', 'Area in Sq. Miles']

# We only take 2020 because that aligns with the U.S. Census in the rural_urban_df
metro = metro[metro['Year'] == 2020]

# add San Francisco Area Sq. Miles. 
metro.loc[-1] = ['San Francisco', 2020, 47.0] 
merge_df = metro.merge(rural_urban_df, on=['County']).drop(columns='Year')
merge_df['People Per Sq. Mile'] = merge_df.get('Population') / merge_df.get('Area in Sq. Miles')
merge_df.sort_values('People Per Sq. Mile', ascending=False, inplace=True)

# We filter by population density
top10_urban = merge_df.sort_values('People Per Sq. Mile').iloc[-10:].get('County').to_list()
top10_rural = merge_df.sort_values('People Per Sq. Mile').iloc[0:10].get('County').to_list()

# Change to uppercase for use in comparing to other df later
merge_df['County'] = [county.upper() for county in merge_df['County']]
top10_urban = [county.upper() for county in top10_urban]
top10_rural = [county.upper() for county in top10_rural]

merge_df.head()
# Out:
#            County  Area in Sq. Miles  Population  \
# 57  SAN FRANCISCO               47.0      873965
# 29         ORANGE              785.0     3186989
# 18    LOS ANGELES             4079.0    10014009
# 0         ALAMEDA              825.0     1682353
# 33     SACRAMENTO             1015.0     1585055
#
#                                           Description  People Per Sq. Mile
# 57  Metro - Counties in metro areas of 1 million p...         18595.000000
# 29  Metro - Counties in metro areas of 1 million p...          4059.858599
# 18  Metro - Counties in metro areas of 1 million p...          2455.015690
# 0   Metro - Counties in metro areas of 1 million p...          2039.215758
# 33  Metro - Counties in metro areas of 1 million p...          1561.630542

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis

# %% [markdown]
# ## Pre-EDA Prep
#
# First, we take a look at our datasets to see if there are any discrepancies over time.

# %%
# Merging data into one df for analaysis 
# adjusting county columns across all df for merge to check for no empty space 
crime_rate_df['County'] = crime_rate_df['County'].str.upper().str.strip()

Ge_df['County'] = Ge_df['County'].str.upper().str.strip()

aq_df['County'] = aq_df['County'].str.upper().str.strip()

realgdp_ca['County'] = realgdp_ca['County'].str.upper().str.strip()

medianinc_ca['County'] = medianinc_ca['County'].str.upper().str.strip()

unemploymentrate['County'] = unemploymentrate['County'].str.upper().str.strip()

temp_env['County'] = temp_env['County'].str.upper().str.strip()


# added to stay consistent with Ge_df
crime_rate_df = crime_rate_df[crime_rate_df['Year']>=2011]

aq_df = aq_df[aq_df['Year']>=2011]

realgdp_ca = realgdp_ca[realgdp_ca['Year']>=2011]

medianinc_ca = medianinc_ca[medianinc_ca['Year']>=2011]

unemploymentrate = unemploymentrate[unemploymentrate['Year']>=2011]

temp_env = temp_env[temp_env['Year']>=2011]


# making sure year consists of all int data types
crime_rate_df['Year']= crime_rate_df['Year'].astype(int)

Ge_df['Year'] = Ge_df['Year'].astype(int)

aq_df['Year'] = aq_df['Year'].astype(int)

realgdp_ca['Year'] = realgdp_ca['Year'].astype(int)

medianinc_ca['Year'] = medianinc_ca['Year'].astype(int)

unemploymentrate['Year'] = unemploymentrate['Year'].astype(int)

temp_env['Year'] = temp_env['Year'].astype(int)

# merging on Crime and Population Data
master_df = pd.merge (crime_rate_df,Ge_df [['County','Year','emmisions']],on= ['County','Year'] ,how='left')

#merging on Air Quality Data
master_df = pd.merge(master_df,aq_df[['County', 'AQI Maximum', 'AQI 90th Percentile', 'AQI Median', 'Year']],on = ['County','Year'],how = 'left' )

# Merging on avg temperature
master_df = pd.merge(master_df, temp_env[['County', 'Year', 'Average Temperature']], on = ['County', 'Year'], how = 'left')

#merging on Median Income Data
master_df = pd.merge(master_df, medianinc_ca[['County','Year', 'income' ]], on = ['County','Year'], how = 'left')

#Merging on GDP Data
master_df = pd.merge(master_df, realgdp_ca[['County','Year', 'gdp_adjusted' ]], on = ['County','Year'], how = 'left')

# Merging on Unemeployment rate
master_df = pd.merge(master_df, unemploymentrate[['County','Year', 'unemployment_rate' ]], on = ['County','Year'], how = 'left')

master_df.head()
# dropping duplicate entries fro the same year and county in the df 
master_df = master_df.drop_duplicates(subset=['Year', 'County'], keep = 'last')
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\2262220733.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aq_df['Year'] = aq_df['Year'].astype(int)

# %%
# Filter to top10 rural and top10 urban
rural_df = master_df[master_df['County'].isin(top10_rural)]
urban_df = master_df[master_df['County'].isin(top10_urban)]

# Exploring Null Values
print('NULL VALUES BELOW')
for i in np.arange(0, len(urban_df.isnull().sum().index)):
    if rural_df.isnull().sum().iloc[i] != 0: 
        print("RURAL: ", rural_df.isnull().sum().index[i], "=", rural_df.isnull().sum().iloc[i])
    if urban_df.isnull().sum().iloc[i] != 0: 
        print("URBAN: ", urban_df.isnull().sum().index[i], "=", urban_df.isnull().sum().iloc[i])
# Out:
# NULL VALUES BELOW
# RURAL:  emmisions = 130
# RURAL:  AQI Maximum = 46
# RURAL:  AQI 90th Percentile = 46
# RURAL:  AQI Median = 46

# %%
# For values with NaN, we will use 0, emissions can be dropped or changed to 0
rural_df = rural_df.replace(np.nan, 0)
rural_df
# Out:
#         County  Year Population  Violent_sum  Property_sum  Violent_rate  \
# 1       ALPINE  2011       1174            7           105           596
# 18        INYO  2011      18582           68           267           366
# 24      LASSEN  2011      34416          120           478           349
# 29    MARIPOSA  2011      18180           55           365           303
# 32       MODOC  2011       9653           42           149           435
# ...        ...   ...        ...          ...           ...           ...
# 1139      MONO  2023    13178.0           53           118           402
# 1148    PLUMAS  2023    18988.0          114           210           600
# 1169    SIERRA  2023     3193.0            5            12           157
# 1170  SISKIYOU  2023    43527.0          207           300           476
# 1178   TRINITY  2023    15940.0           98           187           615
#
#       Property_rate  emmisions  AQI Maximum  AQI 90th Percentile  AQI Median  \
# ...

# %% [markdown]
# ### Environmental EDA
#
# We will look at the top 10 rural and urban counties' environmental data in this section of the EDA. That is, the AQI (Air Quality), Emissions, and Temperature.

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 4))

sns.histplot(rural_df['AQI Median'], label = 'rural', ax = axes[0])
sns.histplot(urban_df['AQI Median'], label = 'urban', ax = axes[0])

sns.histplot(rural_df['AQI Maximum'], label = 'rural', ax = axes[1])
sns.histplot(urban_df['AQI Maximum'], label = 'urban', ax = axes[1])

sns.histplot(rural_df['AQI 90th Percentile'], label = 'rural', ax = axes[2])
sns.histplot(urban_df['AQI 90th Percentile'], label = 'urban', ax = axes[2])


axes[0].legend()
axes[1].legend()
axes[2].legend();

# %%
# Check out the outlier for AQI Median
rural_df[rural_df['AQI Median'] > 80]
# Out:
#      County  Year Population  Violent_sum  Property_sum  Violent_rate  \
# 317  ALPINE  2015       1190            9            35           756
#
#      Property_rate  emmisions  AQI Maximum  AQI 90th Percentile  AQI Median  \
# 317           2941        0.0        177.0                149.0       102.0
#
#      Average Temperature  income  gdp_adjusted  unemployment_rate
# 317            47.208333   50882        112863                7.3

# %% [markdown]
# After searching up Alpine 2015 AQI, it seems that this outlier is not an error. It seems that the air quality was just a little worse for Alpine this year. Moving forward we will remove this outlier. Whereas for the urban counties, there seems to be no issue with outliers there.

# %%
# Check out why so many values are concentrated near value of 0
rural_df[rural_df['AQI Median'] < 1].get('County').unique()
# Out:
# array(['LASSEN', 'MODOC', 'SIERRA', 'ALPINE'], dtype=object)

# %% [markdown]
# It looks like we are missing data here for Lassen, Modoc, Sierra, and Alpine county.

# %%
# Plot some line plots to see the trend over time
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
rural_aqi = rural_df[rural_df['AQI Median'] < 80]
sns.lineplot(rural_aqi[['County', 'Year', 'AQI Median']], x='Year', y='AQI Median', hue='County', ax=axes[0], palette=sns.color_palette('tab10'))
axes[0].set_title('Rural Counties')
sns.lineplot(urban_df, x='Year', y='AQI Median', hue='County', ax=axes[1], palette=sns.color_palette('dark'))
axes[1].set_title('Urban Counties')

plt.subplots_adjust(wspace=0.7)
axes[0].legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
axes[1].legend(loc='center left', bbox_to_anchor=(1.0, 0.5));

# %% [markdown]
# **LEFT:** Most notably, Alpine drops to 0, most likely due to lack of data. And we confirm that Lassen, Modoc, and Sierra stay at a constant value of 0. The rest seem to be steady between the range 40-60 AQI.<br>
# **RIGHT:** We have all data here. The two that stand out are San Diego and Los Angeles. Most urban counties also fluctuate between 40 and 60, with only a Alameda and Contra Costa being >60.
#
# Overall, we see a downward trend with AQI Median towards 2020 to 2025 for rural and especially urban counties. That makes sense, since we had quarantine and the air quality would get better over these years. Later, we will explore if this trend seems consistent with any changes in crime.

# %% [markdown]
# ### Exploring Average Temperature of rural and urban counties

# %%
sns.histplot(rural_df['Average Temperature'], label = 'rural',palette=sns.color_palette('dark'))
sns.histplot(urban_df['Average Temperature'], label = 'urban', palette=sns.color_palette('dark'))

plt.legend()
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\2538637420.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(rural_df['Average Temperature'], label = 'rural',palette=sns.color_palette('dark'))
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\2538637420.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(urban_df['Average Temperature'], label = 'urban', palette=sns.color_palette('dark'))

# %% [markdown]
# As seen above, rural counties are generally cooler than urban counties. Additionally, there doesn't seem to be any outliers and the crossover between the two distributions could be explained by factors like geographical location.

# %% [markdown]
# ## Exploring Emissions for rural and Urban counties with regards to distribution of data

# %% [markdown]
# ##### below is plotted a historgram revealing that there is a dicrepancy in the emission data for rural counties so we need to find out why

# %%
sns.histplot(rural_df['emmisions'], label = 'rural',palette=sns.color_palette('dark'))
sns.histplot (urban_df['emmisions'], label  = 'urban',palette=sns.color_palette('dark'))

plt.legend()
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\1476272013.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(rural_df['emmisions'], label = 'rural',palette=sns.color_palette('dark'))
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\1476272013.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot (urban_df['emmisions'], label  = 'urban',palette=sns.color_palette('dark'))

# %% [markdown]
# #### Let's find out why there is a discrepancy between emissions for rural vs urban counties
# - it turns out that there is no data on emissions for the top 10 rural counties in California which might be due to population bias

# %%
num_zero = rural_df[rural_df['emmisions'] == 0].value_counts().sum()
print (num_zero)
# log tranforming data to shift 0 vals 
rural_df['log_e'] = np.log(rural_df['emmisions'] +1)
# Out:
# 130

# %% [markdown]
# #### Now we explore emissions data with in regards to urbanized counties

# %%
sns.histplot(urban_df['emmisions'],palette=sns.color_palette('dark'))
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\1136441546.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(urban_df['emmisions'],palette=sns.color_palette('dark'))
# <Axes: xlabel='emmisions', ylabel='Count'>

# %% [markdown]
# From our histplot we observe that there is a right skew in our data for Urbanized counties, this may be a result of densely populated counties like San Francisco and LA County which have the highest emissions output over time

# %%
sns.lineplot(data = urban_df, x = 'Year', y ='emmisions',palette=sns.color_palette('dark'))
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\1200096384.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data = urban_df, x = 'Year', y ='emmisions',palette=sns.color_palette('dark'))
# <Axes: xlabel='Year', ylabel='emmisions'>

# %% [markdown]
# From our lmplot we observe that there is an overall downwards trend for emissions over time for Urban counties which may be caused by big county efforts to decrease emissions by relying more on public transport, energy efficient technology, etc.

# %% [markdown]
# ## We will now log transform emissions data for Urban counties to fully understand whether the downwards trend in emissions is actually die to big outliers skewing the data right from the previous histplot

# %%
# log tranforming the emmisions data for emmsiisons for urban 
urban_df['log_e'] = np.log1p(urban_df['emmisions'])
sns.lineplot(data = urban_df, x = 'Year', y =  'log_e' ,palette=sns.color_palette('dark'))
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\1987331048.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   urban_df['log_e'] = np.log1p(urban_df['emmisions'])
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\1987331048.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data = urban_df, x = 'Year', y =  'log_e' ,palette=sns.color_palette('dark'))
# <Axes: xlabel='Year', ylabel='log_e'>

# %% [markdown]
# Overall, even after log transforming the data we observe that there indeed is a downwards trend in emmissions over the years for Urban counties. Seeing this, we may want to look at in comparison to crime rates and average income etc., to further understand how to build our models.

# %% [markdown]
# ## Comparing both log tranformed emissions for rural and urban counties in CA

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
rural_aqi = rural_df[rural_df['log_e'] < 80]
sns.lineplot(rural_aqi[['County', 'Year', 'log_e']], x='Year', y='log_e', hue='County', ax=axes[0], palette=sns.color_palette('tab10'))
axes[0].set_title('Rural Counties')
sns.lineplot(urban_df, x='Year', y='log_e', hue='County', ax=axes[1], palette=sns.color_palette('dark'))
axes[1].set_title('Urban Counties')

plt.subplots_adjust(wspace=0.7)
axes[0].legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
axes[1].legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %% [markdown]
# We note that we contain no data for the rural counties in regards to emissions, but when it comes to emissions data that is logged for urban counties, we note that there is a slightly negative linear relationship between emissions of urban counties and time. However, this is with the exception of counties like San Diego and Orange County, who show a slightly positive linear relationship. We also note that Santa Cruz has relatively lower emissions over time compared to the other counties.

# %% [markdown]
# ## We will now analyze emissions data in relationship to crime with respect to violent property rates to see if there is a relationship

# %%
emissions_v_violent = smf.ols(formula ='Violent_rate ~ emmisions', data = urban_df ).fit()

print (emissions_v_violent.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Violent_rate   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.5155
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):              0.474
# Time:                        18:52:55   Log-Likelihood:                -857.01
# No. Observations:                 130   AIC:                             1718.
# Df Residuals:                     128   BIC:                             1724.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    426.7494     17.784     23.997      0.000     391.561     461.938
# ...

# %% [markdown]
# Looking at the OLS results for emissions predicting violent rate, we observe a p-value of 0.474 > alpha  = 0.05, thus there is not a statistically significant relationship between greenhouse gas emissions for urban counties and violent crime rate. It is also key to note that we also observe a relatively obnoxious Cond. No. potentially suggesting multicollinearity between the two.

# %% [markdown]
# ## Additionally it is key that we take into consideration property crime rate with respect to greenhouse gas emissions for urban counties

# %%
emissions_v_p = smf.ols(formula ='Property_rate ~ emmisions', data = urban_df ).fit()

print (emissions_v_p.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Property_rate   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     3.559
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):             0.0615
# Time:                        18:52:55   Log-Likelihood:                -1095.2
# No. Observations:                 130   AIC:                             2194.
# Df Residuals:                     128   BIC:                             2200.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   2862.5488    111.133     25.758      0.000    2642.653    3082.444
# ...

# %% [markdown]
# When looking at the relationship between Property Crime Rates and Emissions for Urban counties we do not observe a  statistically relationship between the two, considering we obtained a p-value of 0.062> .05 . Additionally we observe a moderately high BIC indicating overfitting of data in our OLS model.

# %% [markdown]
# ## Now we look to see if there is a statistically significant relationship betweeen AQI median for Urban counties and Violent crime rates

# %%
median_temp_v_violent = smf.ols(formula = 'Q("AQI Median") ~ Violent_rate', data = urban_df).fit()

print (median_temp_v_violent.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Q("AQI Median")   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                   0.01035
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):              0.919
# Time:                        18:52:55   Log-Likelihood:                -511.54
# No. Observations:                 130   AIC:                             1027.
# Df Residuals:                     128   BIC:                             1033.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       52.6930      2.893     18.216      0.000      46.969      58.417
# ...

# %% [markdown]
# Looking at the results of the OLS, we obtain a p-value of 0.919, indicating no statistically significant relationship between AQI median for Urban Counties and Violent crime rates. Addtionally it is key to note that we obtain a BIC of 1027, thus proving that our model is fitting our data relatively well between AQI Median and Violent Crime rates.

# %%
median_temp_v_violent = smf.ols(formula = 'Q("AQI Median") ~ Property_rate', data = urban_df).fit()

print (median_temp_v_violent.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Q("AQI Median")   R-squared:                       0.131
# Model:                            OLS   Adj. R-squared:                  0.124
# Method:                 Least Squares   F-statistic:                     19.22
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):           2.40e-05
# Time:                        18:52:55   Log-Likelihood:                -502.45
# No. Observations:                 130   AIC:                             1009.
# Df Residuals:                     128   BIC:                             1015.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        64.0132      2.718     23.547      0.000      58.634      69.392
# ...

# %% [markdown]
# Looking at the relationship between AQI Median and property rate, there is signficant statistical evidence showing a relationship between AQI Median and Property crime rates for urban counties with a BIC of 1009 and a p-value >0.000 >0.05 = alpha.

# %%
sns.lmplot(x = 'Property_rate', y = 'AQI Median', data= rural_df,palette=sns.color_palette('dark'))

# %% [markdown]
# From our lmplot, we observe that Property rate and AQI Median would fit a linear model, but it is important to remember that there may exist many outliers between the two.

# %% [markdown]
# ## We now further look at environmental degradation with respect to crime for rural areas and begin OLS

# %%
median_temp_v_violent = smf.ols(formula = 'Q("AQI Median") ~ Violent_rate', data = rural_df).fit()

print (median_temp_v_violent.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Q("AQI Median")   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.1329
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):              0.716
# Time:                        18:52:56   Log-Likelihood:                -594.24
# No. Observations:                 130   AIC:                             1192.
# Df Residuals:                     128   BIC:                             1198.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       25.9193      4.633      5.595      0.000      16.753      35.086
# ...

# %% [markdown]
# We observe that our P-value is significantly high following the regression so we will dive deeper to find out why there is no statistical evidence show a relationship between violent crime rate and Median AQI for rural counties.

# %%
sns.lmplot(x = 'Violent_rate', y = 'AQI Median', data= rural_df,palette=sns.color_palette('dark'))

# %% [markdown]
# From our lmplot, we visually see that violent crime rates and AQI Median would not fit a linear model well at all

# %% [markdown]
# ## Additionally we look at Property Crime Rate with respect to AQI Median with regards to Environmental Degradation

# %%
median_temp_v_violent = smf.ols(formula = 'Q("AQI Median") ~ Property_rate', data = rural_df).fit()

print (median_temp_v_violent.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Q("AQI Median")   R-squared:                       0.061
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     8.243
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):            0.00479
# Time:                        18:52:56   Log-Likelihood:                -590.25
# No. Observations:                 130   AIC:                             1185.
# Df Residuals:                     128   BIC:                             1190.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        16.2699      4.374      3.720      0.000       7.616      24.924
# ...

# %% [markdown]
# When looking at the results of the OLS, there is statistically significant evidence with a p-value of 0.005 > alpha = .05, signifying that there is relationship between AQI median and property crime rates. This shows that environmental degradation with respect to AQI Median may be playing a significant role in property crime rates for Rural Counties.

# %% [markdown]
# ## Now we want to look at the relationship between Average Temperature and Crime Rates in Rural and Urban Areas

# %% [markdown]
# ### Is the relationship between Average Temperature and Property Crime Rates of Rural and Urban Counties statstically significant?

# %%
avg_temp_v_property = smf.ols(formula = 'Q("Average Temperature") ~ Property_rate', data = rural_df).fit()

print (avg_temp_v_property.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Q("Average Temperature")   R-squared:                       0.009
# Model:                                  OLS   Adj. R-squared:                  0.001
# Method:                       Least Squares   F-statistic:                     1.148
# Date:                      Wed, 11 Jun 2025   Prob (F-statistic):              0.286
# Time:                              18:52:56   Log-Likelihood:                -397.04
# No. Observations:                       130   AIC:                             798.1
# Df Residuals:                           128   BIC:                             803.8
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# When looking at rural counties, we  observe that there is not statistical evidence showing the relationship between property crime rates and average temperature for rural counties. p-value = 0.455 < alpha = 0.05. We fail to reject the null at alpha = 0.05.

# %%
avg_temp_v_property = smf.ols(formula = 'Q("Average Temperature") ~ Property_rate', data = urban_df).fit()

print (avg_temp_v_property.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Q("Average Temperature")   R-squared:                       0.194
# Model:                                  OLS   Adj. R-squared:                  0.188
# Method:                       Least Squares   F-statistic:                     30.79
# Date:                      Wed, 11 Jun 2025   Prob (F-statistic):           1.59e-07
# Time:                              18:55:37   Log-Likelihood:                -304.63
# No. Observations:                       130   AIC:                             613.3
# Df Residuals:                           128   BIC:                             619.0
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %% [markdown]
# When looking at urban counties, we  observe that there is statistical evidence showing the relationship between property crime rates and average temperature for urban counties. p-value = 0.000 < alpha = 0.05. We reject the null at alpha = 0.05.

# %% [markdown]
# ### Is the relationship between Average Temperature and Violent Crime Rates of Rural and Urban Counties statstically significant?

# %%
avg_temp_v_violent = smf.ols(formula = 'Q("Average Temperature") ~ Violent_rate', data = rural_df).fit()

print (avg_temp_v_violent.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Q("Average Temperature")   R-squared:                       0.001
# Model:                                  OLS   Adj. R-squared:                 -0.006
# Method:                       Least Squares   F-statistic:                    0.1882
# Date:                      Wed, 11 Jun 2025   Prob (F-statistic):              0.665
# Time:                              18:58:00   Log-Likelihood:                -397.53
# No. Observations:                       130   AIC:                             799.1
# Df Residuals:                           128   BIC:                             804.8
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# When looking at rural counties, we  observe that there is not statistical evidence showing the relationship between violent crime rates and average temperature for rural counties. p-value = 0.406 < alpha = 0.05. We fail to reject the null at alpha = 0.05.

# %%
avg_temp_v_violent = smf.ols(formula = 'Q("Average Temperature") ~ Violent_rate', data = urban_df).fit()

print (avg_temp_v_violent.summary())
# Out:
#                                OLS Regression Results
# ...
# Dep. Variable:     Q("Average Temperature")   R-squared:                       0.044
# Model:                                  OLS   Adj. R-squared:                  0.036
# Method:                       Least Squares   F-statistic:                     5.851
# Date:                      Wed, 11 Jun 2025   Prob (F-statistic):             0.0170
# Time:                              18:58:27   Log-Likelihood:                -315.73
# No. Observations:                       130   AIC:                             635.5
# Df Residuals:                           128   BIC:                             641.2
# Df Model:                                 1
# Covariance Type:                  nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# When looking at urban counties, we  observe that there is statistical evidence showing the relationship between violent crime rates and average temperature for urban counties. p-value = 0.002 < alpha = 0.05. We reject the null at alpha = 0.05.

# %% [markdown]
# ### Rural/Urban Counties and GDP

# %%
#plotting rural counties and GDP
plt.hist(rural_df['gdp_adjusted'], bins=30)
plt.show()
sns.boxplot(x=rural_df['gdp_adjusted'],palette=sns.color_palette('dark'))
plt.show()
rural_df['gdp_adjusted'].describe()
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\3704216651.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=rural_df['gdp_adjusted'],palette=sns.color_palette('dark'))
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\3704216651.py:4: UserWarning: The palette list has more values (10) than needed (1), which may not be intended.
#   sns.boxplot(x=rural_df['gdp_adjusted'],palette=sns.color_palette('dark'))
# count    1.300000e+02
# mean     7.506305e+05
# std      4.808788e+05
# min      8.613700e+04
# 25%      3.661752e+05
# 50%      8.132405e+05
# 75%      1.134019e+06
# max      1.849450e+06
# Name: gdp_adjusted, dtype: float64

# %% [markdown]
# ##### Based on this initial plot for GDP in rural counties, it appears to be heavily skewed to the right with no apparent extreme outliers. Interestingly, even though these are the lowest ten counties, there is still a wide spread in GDP data (~85k to 1.8m!). This is to be expected given California's wide range of income sectors (natural resources, tourism, and infrastructure could all play a part), so we can log transform these. While there are huge relative differences across counties, there doesn't appear to be any outright outliers, though it's important to keep that in mind moving forward.

# %%
#log transform
rural_df['log_gdp'] = np.log1p(rural_df['gdp_adjusted'])
sns.lineplot(data = rural_df, x='Year', y='log_gdp')
# Out:
# <Axes: xlabel='Year', ylabel='log_gdp'>

# %% [markdown]
# ##### Looks like GDP across the rural counties has remained relatively constant throughout the years, with a bit of a dip in 2020, which is to be expected given the pandemic.

# %%
#plotting urban counties and GDP
plt.hist(urban_df['gdp_adjusted'], bins=30)
plt.show()
sns.boxplot(x=urban_df['gdp_adjusted'],palette=sns.color_palette('dark'))
plt.show()
urban_df['gdp_adjusted'].describe()
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\2877600124.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=urban_df['gdp_adjusted'],palette=sns.color_palette('dark'))
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\2877600124.py:4: UserWarning: The palette list has more values (10) than needed (1), which may not be intended.
#   sns.boxplot(x=urban_df['gdp_adjusted'],palette=sns.color_palette('dark'))
# count    1.300000e+02
# mean     2.063634e+08
# std      1.899410e+08
# min      1.264814e+07
# 25%      8.397843e+07
# 50%      1.500888e+08
# 75%      2.381907e+08
# max      8.019674e+08
# Name: gdp_adjusted, dtype: float64

# %% [markdown]
# ##### It appears that there are a few counties doing a lot of the heavy lifting in the top urban counties (San Francisco and Los Angeles come to mind), which are unsurprisingly driving a heavy right skew with tons of outliers compared to the rural counties. Let's see who's driving this:

# %%
#isolate upper bound of gdp data
q1 = urban_df['gdp_adjusted'].quantile(0.25)
q3 = urban_df['gdp_adjusted'].quantile(0.75)
iqr = q3 - q1
upper = q3 + 1.5 * iqr
urb_gdpout = urban_df[urban_df['gdp_adjusted'] > upper]
urb_gdpout.head(10)
# Out:
#           County  Year Population  Violent_sum  Property_sum  Violent_rate  \
# 26   LOS ANGELES  2011    9872846        46116        228174           467
# 105  LOS ANGELES  2012    9937750        44556        232266           448
# 184  LOS ANGELES  2013    9995638        40384        228419           404
# 263  LOS ANGELES  2014   10037944        42725        217493           426
# 342  LOS ANGELES  2015   10072887        50466        240050           501
# 421  LOS ANGELES  2016   10087542        56351        252224           559
# 500  LOS ANGELES  2017   10107312        59924        248714           593
# 579  LOS ANGELES  2018   10107841        58567        237814           579
# 658  LOS ANGELES  2019   10067476        56416        224192           560
# 895  LOS ANGELES  2020   10014009        54600        213377           545
#
#      Property_rate     emmisions  AQI Maximum  AQI 90th Percentile  \
# 26            2311  1.914229e+07        218.0                151.0
# ...

# %% [markdown]
# ##### As expected, Los Angeles is responsible for all the outliers in GDP for the urban areas. Let's log transform this:

# %%
urban_df['log_gdp'] = np.log1p(urban_df['gdp_adjusted'])
sns.lineplot(data = urban_df, x='Year', y='log_gdp', palette=sns.color_palette('dark'))
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\1110381989.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   urban_df['log_gdp'] = np.log1p(urban_df['gdp_adjusted'])
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\1110381989.py:2: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data = urban_df, x='Year', y='log_gdp', palette=sns.color_palette('dark'))
# <Axes: xlabel='Year', ylabel='log_gdp'>

# %% [markdown]
# ##### It appears as though the urban counties have experienced a steady growth in their economies when compared to their rural counterparts, with the same dip around the pandemic.

# %% [markdown]
# ## We will now run linear regression analyses to see if there is a direct relationship between the economic data, against rural and urban counties in California; addtionally in regards to crime rate as well

# %%
adj_gdp_v_violent_crime = smf.ols(formula='gdp_adjusted ~ Violent_rate',data = rural_df).fit()

print (adj_gdp_v_violent_crime.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           gdp_adjusted   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.2808
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):              0.597
# Time:                        18:52:57   Log-Likelihood:                -1884.7
# No. Observations:                 130   AIC:                             3773.
# Df Residuals:                     128   BIC:                             3779.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     7.956e+05   9.48e+04      8.393      0.000    6.08e+05    9.83e+05
# ...

# %% [markdown]
# Intepreting the results of the ols regression for the realtionship between adjusted gdp and violent crime rate we see that we observe a high p value of .597 signifying no statistical relationship between violent crime rate and adjusted gdp for rural counties. This again may come as a result of the constant growth of rural county's as observed earlier. Additionally we observe a relatively high Bayesian indicator criterion, meaning that our model is not fitting the data in a good manner.

# %%
adj_gdp_v_property_crime = smf.ols(formula='Property_rate ~ gdp_adjusted',data = rural_df).fit()

print (adj_gdp_v_property_crime.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Property_rate   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9275
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):              0.337
# Time:                        18:52:57   Log-Likelihood:                -1057.3
# No. Observations:                 130   AIC:                             2119.
# Df Residuals:                     128   BIC:                             2124.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     1713.8261    135.402     12.657      0.000    1445.909    1981.743
# ...

# %% [markdown]
# Addtionally when looking at the relationship between adjusted GDP and Property crime rate, we still observe way too high of a p-value to show there is a statistically significant relationship between property crime and rural county GDP. This is possibly due the relatively constant gdp for rural counties as shown above. Addtionally in this OLS, we still see the same relatively high BIC but particularly lower indicating that our model is better fitting our data.

# %% [markdown]
# ## Now we will look at Urban Counties in regards to GDP and Crime

# %%
adj_gdp_v_violent_crime = smf.ols(formula='Violent_rate ~ gdp_adjusted',data = urban_df).fit()

print (adj_gdp_v_violent_crime.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Violent_rate   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.140
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):              0.288
# Time:                        18:52:57   Log-Likelihood:                -856.69
# No. Observations:                 130   AIC:                             1717.
# Df Residuals:                     128   BIC:                             1723.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept      414.7489     23.031     18.008      0.000     369.178     460.320
# ...

# %% [markdown]
# Additionally when looking at urban counties, we  observe that there is no statistical evidence showing the relationship between violent crime rates and gdp for urban counties. p-value = 0.288 > alpha = 0.05. We reject the null at alpha = 0.05.

# %%
adj_gdp_v_property_crime = smf.ols(formula='Property_rate ~ gdp_adjusted',data = urban_df).fit()

print (adj_gdp_v_property_crime.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Property_rate   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                  0.019
# Method:                 Least Squares   F-statistic:                     3.450
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):             0.0655
# Time:                        18:52:57   Log-Likelihood:                -1095.3
# No. Observations:                 130   AIC:                             2195.
# Df Residuals:                     128   BIC:                             2200.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     2959.5590    144.332     20.505      0.000    2673.973    3245.145
# ...

# %% [markdown]
# Additionally  when running our OLS betweeen Property Crime Rate and adjusted gdp for urban counties we dont  observe a statistically significant p-value which is less than .05. THus there does not exist a statistically signficant relationship between Property Crime Rates and adjusted gdp for urban counties which is why we might want look further into using a decision tree machine learning method.

# %%
sns.lineplot(data = unemploymentrate, x = 'Year', y = 'unemployment_rate', palette=sns.color_palette('dark'))
plt.show()
sns.lineplot(data = medianinc_ca, x = 'Year', y = 'income',palette=sns.color_palette('dark'))
plt.show()
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\3009669777.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data = unemploymentrate, x = 'Year', y = 'unemployment_rate', palette=sns.color_palette('dark'))
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\3009669777.py:3: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(data = medianinc_ca, x = 'Year', y = 'income',palette=sns.color_palette('dark'))

# %% [markdown]
# From the plots above, we observe that there tends to be a positive trend in income as years progress which we would expect due to inflation and a negative relationship between unemployment rates, with a spike in 2020 which may have been caused by the COVID_19 pandemic. This leads us to look at this at the county level for urban and rural counties.

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
sns.lineplot(rural_aqi[['County', 'Year', 'unemployment_rate']], x='Year', y='unemployment_rate', hue='County', ax=axes[0], palette=sns.color_palette('tab10'))
axes[0].set_title('Rural Counties')
sns.lineplot(urban_df, x='Year', y='unemployment_rate', hue='County', ax=axes[1], palette=sns.color_palette('dark'))
axes[1].set_title('Urban Counties')

plt.subplots_adjust(wspace=0.7)
axes[0].legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
axes[1].legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %% [markdown]
# Looking at the plots above fro rural and urban counties in regards to unemployment rate we see that bot rural and urban counties faced a significant spike in unemployment rates in 2020 whihc again may be explained by the 2020 covid pandemic. Though it is key to note that the unemployment rate spike was signifcantly bigger spiking at 16% opposed to about 13% for urban couties all around

# %% [markdown]
# ## We will now begin analyses to see its relationship to violent and property crime rates in regards to the economy, with respect to Urban and Rural Counties

# %% [markdown]
# First we begin by looking at Urban Counties

# %%
unemployment_v_property_crime = smf.ols(formula='Property_rate ~ unemployment_rate',data = urban_df).fit()

print (unemployment_v_property_crime.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Property_rate   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.5918
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):              0.443
# Time:                        18:52:58   Log-Likelihood:                -1096.7
# No. Observations:                 130   AIC:                             2197.
# Df Residuals:                     128   BIC:                             2203.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          2930.6717    240.484     12.187      0.000    2454.834    3406.510
# ...

# %% [markdown]
# Looking at our OLS model, there is no statistically significant evidence indicating a relationship between unemployment rates for Urban Counties and Property crime rates as we recieved a p-value = 0.285 > 0.05. Though it is key to note that our BIC is 2197 which is pretty high, indicating that our model may be overfitting our data.

# %%
unemployment_v_Violent_crime = smf.ols(formula='Violent_rate ~ unemployment_rate',data = urban_df).fit()

print (unemployment_v_Violent_crime.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Violent_rate   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                  0.005449
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):              0.941
# Time:                        18:52:58   Log-Likelihood:                -857.27
# No. Observations:                 130   AIC:                             1719.
# Df Residuals:                     128   BIC:                             1724.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           430.3103     38.122     11.288      0.000     354.879     505.741
# ...

# %% [markdown]
# Based of our OLS model we can conclude that there is not a statistically significant relationship between violent crime rates and unemployment rates since we observed a p-value which is about 0.941 which is greater than an alpha = 0.05. Though we do have pretty high BIC indicating that our model may be overfitting our data

# %% [markdown]
# ## We now look at Rural counties in regards to unemployment rates and crime

# %%
unemployment_v_property_crime = smf.ols(formula='Property_rate ~ unemployment_rate',data = rural_df).fit()

print (unemployment_v_property_crime.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          Property_rate   R-squared:                       0.044
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     5.931
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):             0.0163
# Time:                        18:52:58   Log-Likelihood:                -1054.8
# No. Observations:                 130   AIC:                             2114.
# Df Residuals:                     128   BIC:                             2119.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept          1147.1342    200.711      5.715      0.000     749.994    1544.275
# ...

# %% [markdown]
# When it comes to rural counties, we observe a p-value of 0.016 which is just small enough to be statistically significant, showing a relationship between a rural county’s unemployment rate and property crime. This can be further used in a decision tree when it comes to our machine learning models.

# %%
unemployment_v_Violent_crime = smf.ols(formula='Violent_rate ~ unemployment_rate',data = rural_df).fit()

print (unemployment_v_Violent_crime.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:           Violent_rate   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.2505
# Date:                Wed, 11 Jun 2025   Prob (F-statistic):              0.618
# Time:                        18:52:58   Log-Likelihood:                -901.19
# No. Observations:                 130   AIC:                             1806.
# Df Residuals:                     128   BIC:                             1812.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           526.6274     61.555      8.555      0.000     404.831     648.424
# ...

# %% [markdown]
# When it comes to rural counties, specifically unemployment rates and violent crime rates, we do not see a statistically significant p-value to conclude a relationship between violent crime rates and unemployment rates. Additionally we obtain a BIC of 1806 which means our model is somewhat fitting our data well but also overfitting.

# %% [markdown]
# ## Recap On EDA

# %% [markdown]
# When it comes to Environmental Degradation data with respect to Crime rates for rural and urban counties, we observe the following:
# - There is a significant statistical relationship between AQI Median and Property Crime rates for urban counties in CA
# - There is a significant statistical relationship between AQI Median and Property Crime Rates for rural counties in CA
# - There is a significant statistical relationship between Average Temperature and Property Crime rates for urban counties in CA
# - There is a significant statistical relationship between Average Temperature and Violent Crime rates for urban counties in CA
#
# When it comes to Economic data with respect to crime rates for rural and urban counties, we observe the following:
# - There is a significant statistical relationship between unemployment rates and Property crime data for rural counties in CA
#
# Thus when it comes to our machine learning model we'd want to consider looking potentially at a decision tree for Environmental degradation with respect to AQI and Property Crime rates for both rural and urban counties in CA, furthermore we consider running PCA for all the other analyses conducted by our OLS models due to the high Cond.no that we observed in the results to further make sure the right variables are being using for our final model and potentially get rid of the suggested multicollinearity in our final model  .

# %% [markdown]
# ## Modeling a New Economic Health Measure

# %% [markdown]
# Now, we want to see if we can use the data from our analysis to create an alternative for GDP. For this, we'll use an Index-Based Heuristic model, as we can control the weights of variables based on our analytical findings, reward factors we find to be positive, and penalize ones we find to be negative. It's also fast and allows us to easily compare this measure to the original GDP of the county, unlike a predictive model which would take longer and would not be totally applicable as we are not necessarily trying to predict any of these variables but to just apply what we do have to this measure. We'll call this new measure the Quality of Life and Economy Indicator, or QLEI for short (pronounced 'clay').
#
# For reference, GDP uses a basic formula that sums up private and public expenditures. GPI uses a similar measure, but adds capital growth and welfare contributions while subtracting costs of crime and environmental degradation. In the US, both use USD as the units for all variables. Ideally, with our QLEI model we can mimic what GPI does, but with pure data instead of purely spending. We'll also use a PCA model to compare against our primary. This model will serve as a neutral benchmark to compare against the QLEI without bias to see if our findings align with how the variables actually interact.

# %%
#define function for index-based model
def compute_qlei(df, positive_vars, negative_vars, normalize=True):
    """
    computes an economic health index by summing normalized positive variables
    and subtracting normalized negative variables

    parameters:
    - df: input df
    - positive_vars: list of postive variables
    - negative_vars: list of negative variables
    - normalize: whether to apply MinMax normalization (default True)

    return:
    - df with new column 'qlei_index'
    """
    #combine variables
    vars_to_use = positive_vars + negative_vars
    df_model = df.copy()
    #normalize variables
    if normalize == True:
        scaler = MinMaxScaler()
        df_model[vars_to_use] = scaler.fit_transform(df_model[vars_to_use])
    df_model['qlei'] = df_model[positive_vars].sum(axis=1) - df_model[negative_vars].sum(axis=1)
    return df_model

#define function for pca-based model
def compute_pca_index(df, feature_vars, normalize=True):
    """
    computes the first principal component of selected features as a PCA-based QLEI.

    parameters:
    - df: Input DataFrame
    - feature_vars: list of variables to include in PCA
    - normalize: whether to apply MinMax normalization (default True)

    return:
    - df with new column 'pca_health_index'
    - array of explained variance ratio
    """
    #copy df
    df_model = df.copy()
    #normalize variables
    if normalize == True:
        scaler = MinMaxScaler()
        df_model[feature_vars] = scaler.fit_transform(df_model[feature_vars])
    pca = PCA(n_components=1)
    df_model['pca'] = pca.fit_transform(df_model[feature_vars])[:, 0]
    return df_model, pca.explained_variance_ratio_

# %%
def compare_qlei_pca_gdp(df):
    """
    compares QLEI and PCA scores to original GDP w/ rankings, delta columns, & correlation matrix

    parameters:
    - df: df output from qlei & pca functions

    returns:
    - DataFrame with added ranking and delta columns
    - Correlation matrix (as a DataFrame)
    """
    df = df.copy()
    #rankings
    df['gdp_rank'] = df['gdp_adjusted'].rank(ascending=False)
    df['qlei_rank'] = df['qlei'].rank(ascending=False)
    df['pca_rank'] = df['pca'].rank(ascending=False)

    #delta comparisons
    df['qlei_vs_gdp'] = df['qlei_rank'] - df['gdp_rank']
    df['pca_vs_gdp'] = df['pca_rank'] - df['gdp_rank']

    #correlation matrix
    corr = df[['qlei', 'pca', 'gdp_adjusted']].corr()

    #scatterplots
    sns.set_theme(style="whitegrid", palette="pastel")

    plt.figure(figsize=(6, 5))
    sns.scatterplot(data=df, x='gdp_adjusted', y='qlei', hue='Year', palette='viridis', s=60, edgecolor='black')
    plt.title('QLEI vs GDP')
    plt.xlabel('GDP (adjusted)')
    plt.ylabel('QLEI')
    plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()

    plt.figure(figsize=(6, 5))
    sns.scatterplot(data=df, x='qlei', y='pca', hue='Year', palette='magma', s=60, edgecolor='black')
    plt.title('QLEI vs PCA')
    plt.xlabel('QLEI')
    plt.ylabel('PCA')
    plt.legend(title='Year', bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.tight_layout()
    plt.show()
    
    return df, corr

# %% [markdown]
# Now, we apply our QLEI model and see how it fares against GDP and our PCA model. We'll assign a positive weight to median income and GDP and negative weight to property/violent crime rates, and unemployment rates as a base. Ideally, we'd find more positive and negative factors based on our analysis, however, air quality was the only statistically significant correlation we found to crime rates; we'll apply that to the negative weighted factors.
#
# First, we look at urban data:

# %%
#Assign positive and negative-weighted factors
p_var = ['income','gdp_adjusted']
n_var = ['Property_rate','AQI Median', 'unemployment_rate', 'Violent_rate']
f_var = p_var + n_var
#Compare urban qlei with gdp and pca
qlei_urban = compute_qlei(urban_df,p_var,n_var,normalize=True)
qlei_urban2, _ = compute_pca_index(qlei_urban, f_var, normalize=True)

urban_comp, urban_corr = compare_qlei_pca_gdp(qlei_urban2)
urban_corr
# Out:
#                   qlei       pca  gdp_adjusted
# qlei          1.000000 -0.396754      0.119732
# pca          -0.396754  1.000000      0.624228
# gdp_adjusted  0.119732  0.624228      1.000000

# %% [markdown]
# We can see here there's a mild positive correlation between QLEI and GDP and a moderate negative correlation between QLEI and PCA.

# %%
qlei_rural = compute_qlei(rural_df,p_var,n_var, normalize = True)
qlei_rural2, _ = compute_pca_index(qlei_rural,f_var, normalize =True)

rural_comp, rural_corr = compare_qlei_pca_gdp(qlei_rural2)
rural_corr
# Out:
#                   qlei       pca  gdp_adjusted
# qlei          1.000000  0.401703      0.444665
# pca           0.401703  1.000000      0.906879
# gdp_adjusted  0.444665  0.906879      1.000000

# %% [markdown]
# Interestingly, we see a much different result from our urban data. We see a stronger positive correlation for QLEI vs. GDP, and a positive correlation for QLEI vs. PCA. This suggests there may be less of an effect of negative factors in rural counties weighted against GDP.
#
# Let's see which counties have the greatest discrepancies between QLEI and GDP rank.

# %%
def qlei_differences(df, top_n=10):
    """
    highlights counties with the biggest differences between QLEI and GDP rank

    parameters:
    - df: df with 'County', 'Year', 'qlei_rank', 'gdp_rank'
    - top_n: number of largest positive and negative gaps to return

    returns:
    - qlei_higher: QLEI ranked better than GDP (undervalued by GDP)
    - gdp_higher: GDP ranked better than QLEI (overvalued by GDP)
    """
    df = df.copy()
    df['qlei_vs_gdp'] = df['qlei_rank'] - df['gdp_rank']
    qlei_higher = df.sort_values('qlei_vs_gdp').head(top_n)
    gdp_higher = df.sort_values('qlei_vs_gdp', ascending=False).head(top_n)
    return qlei_higher[['County', 'Year', 'qlei_rank', 'gdp_rank', 'qlei_vs_gdp']], \
           gdp_higher[['County', 'Year', 'qlei_rank', 'gdp_rank', 'qlei_vs_gdp']]

# %%
#look at differences between qlei and gdp for urban counties
urb_qlei_high, urb_gdp_high = qlei_differences(urban_comp, top_n=10)

print(urb_qlei_high)
print(urb_gdp_high)

plot_urb_qlei = urb_qlei_high.copy()
plot_urb_qlei = plot_urb_qlei.sort_values("qlei_vs_gdp")

plt.figure(figsize=(10, 6))
sns.barplot(data=plot_urb_qlei, y="County", x="qlei_vs_gdp", palette="magma")

plt.axvline(0, color='gray', linestyle='--')
plt.title("Counties Where GDP Ranks Higher Than QLEI")
plt.xlabel("QLEI Rank – GDP Rank")
plt.ylabel("County")
plt.tight_layout()
plt.show()

plot_urb_gdp = urb_gdp_high.copy()
plot_urb_gdp = plot_urb_gdp.sort_values("qlei_vs_gdp")

plt.figure(figsize=(10, 6))
sns.barplot(data=plot_urb_gdp, y="County", x="qlei_vs_gdp", palette="magma")

plt.axvline(0, color='gray', linestyle='--')
plt.title("Counties Where GDP Ranks Higher Than QLEI")
plt.xlabel("QLEI Rank – GDP Rank")
plt.ylabel("County")
plt.tight_layout()
plt.show()
# Out:
#             County  Year  qlei_rank  gdp_rank  qlei_vs_gdp
# 1166    SANTA CRUZ  2023       27.0     119.0        -92.0
# 1087    SANTA CRUZ  2022       33.0     120.0        -87.0
# 1035  CONTRA COSTA  2022       26.0     105.0        -79.0
# 640   CONTRA COSTA  2019       24.0     102.0        -78.0
# 372      SAN MATEO  2015       12.0      89.0        -77.0
# 1114  CONTRA COSTA  2023       28.0     103.0        -75.0
# 293      SAN MATEO  2014       19.0      93.0        -74.0
# 561   CONTRA COSTA  2018       37.0     108.0        -71.0
# 956   CONTRA COSTA  2021       35.0     104.0        -69.0
# 609      SAN MATEO  2018        6.0      74.0        -68.0
#           County  Year  qlei_rank  gdp_rank  qlei_vs_gdp
# 26   LOS ANGELES  2011      121.0      13.0        108.0
# 105  LOS ANGELES  2012      118.0      12.0        106.0
# 895  LOS ANGELES  2020      109.0       6.0        103.0
# 184  LOS ANGELES  2013      104.0      11.0         93.0
# ...

# %% [markdown]
# It appears that Santa Cruz, Contra Costa, and San Mateo perform better than pure GDP in QLEI, with Los Angeles dominating the lower rankings, which may suggest that their quality of life is much lower by comparison to its economic output. It's worth noting that they represent both ends of the spectrum in regards to GDP; counties like LA and SD, with higher population densities and GDP's, may have lower quality of life than GDP suggests based on the QLEI model, with the negative factors outweighing GDP by a greater margin than in the lower-GDP counties. Let's see if this tracks with the rural counties as well.

# %%
#look at differences between qlei and gdp for rural counties
rur_qlei_high, rur_gdp_high = qlei_differences(rural_comp, top_n=10)

print(rur_qlei_high)
print(rur_gdp_high)

plot_rur_qlei = rur_qlei_high.copy()
plot_rur_qlei = plot_rur_qlei.sort_values("qlei_vs_gdp")

plt.figure(figsize=(10, 6))
sns.barplot(data=plot_rur_qlei, y="County", x="qlei_vs_gdp", palette="pastel")

plt.axvline(0, color='gray', linestyle='--')
plt.title("Counties Where GDP Ranks Higher Than QLEI")
plt.xlabel("QLEI Rank – GDP Rank")
plt.ylabel("County")
plt.tight_layout()
plt.show()

plot_rur_gdp = rur_gdp_high.copy()
plot_rur_gdp = plot_rur_gdp.sort_values("qlei_vs_gdp")

plt.figure(figsize=(10, 6))
sns.barplot(data=plot_rur_gdp, y="County", x="qlei_vs_gdp", palette="pastel")

plt.axvline(0, color='gray', linestyle='--')
plt.title("Counties Where GDP Ranks Higher Than QLEI")
plt.xlabel("QLEI Rank – GDP Rank")
plt.ylabel("County")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\cjjen\AppData\Local\Temp\ipykernel_7256\3100348315.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=plot_rur_qlei, y="County", x="qlei_vs_gdp", palette="pastel")
#       County  Year  qlei_rank  gdp_rank  qlei_vs_gdp
# 1169  SIERRA  2023       10.0     120.0       -110.0
# 1090  SIERRA  2022       15.0     119.0       -104.0
# 695   SIERRA  2019       19.0     121.0       -102.0
# 1011  SIERRA  2021       29.0     127.0        -98.0
# 932   SIERRA  2020       31.0     126.0        -95.0
# 616   SIERRA  2018       33.0     122.0        -89.0
# 1107  ALPINE  2023       28.0     114.0        -86.0
# 537   SIERRA  2017       42.0     128.0        -86.0
# 379   SIERRA  2015       60.0     130.0        -70.0
# 458   SIERRA  2016       66.0     124.0        -58.0
#        County  Year  qlei_rank  gdp_rank  qlei_vs_gdp
# ...

# %% [markdown]
# QLEI seems to be really strong compared to GDP in Sierra County in particular. It's more of a mixed bag for higher GDP. There seems to be less of a clear distinction here. However, Sierra county ranks in the middle for population density, and all four of the counties with a higher GDP rank are dispersed throughout the top ten rural counties.

# %% [markdown]
# ## Interpreting QLEI vs. GDP
# -  Using PCA we further adress multicolinearity and see that our data as a whole shows that economic and environmental degradation data do further weigh on a county's GDP which further supplements the idea that our new economic model CLEI does seem to be accurate in showing a more wholistic view of how we can measure economic that takes into consideration other factors that can have an impact on economic health. Since GDP looks at total economic output, counties with high GDP with high social and environmental costs can get punished by QLEI to a greater extent, and it appears that the counties with the highest GDP still have disproportionately high crime and environmental degradation to the degree that they experience the lowest drops from GDP to QLEI rank. The population density disparity disappears when looking at rural counties, which may suggest that QLEI is more of a reliable measure for rural counties than urban counties.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# When it comes to dealing with ethics for our project, there may be potential county bias in the data available since it may be the case that there are missing counties that are underrepresented in the available government datasets listed above. That is, Lassen, Modoc, Sierra, and Yuba.
# Additionally, there may be a confounding variable as not all crime and unemployment may be accounted for if not reported to the government. Though a confounding variable, the data collected from websites such as openjustice.doj.ca.gov permits the public usage of the data from their webiste, noting that their website public data is made sure to not include personal information of minors and or use copyrighted material. Furthermore, there may be bias in our statistical analyses when it comes to looking at the rate of crime rate for a specific high income cities which can bias our interpretations of the data. Additionally there may be bias in looking at the rate of Carbon Dioxide Gas emmisions in metric tons when looking at big counties in California. This may cause underepresented counties to not get the economic support from California to better their air quality when they most need it.<br>
#
# To address these issues, we will explore what missing counties there are in the datasets and why they are underrepresented. That way, we can transparently report these reasons as factors that can impact our intrepretation when we analyze our data. For instance, findings that indicate a strong relationship between our variables and crime rate may not be applicable to rural areas. Furthermore, regarding data collections, data regarding crime and umemployment are tracked by the government, but this is something out of our scope of responsibilities. Instead, we can acknowledge that a negative may be consistent with a 'false negative' because of the underrepresentation when interpreting the relationship between our variables and crime. In this understanding, we may not be able to say for certain that findings of 'no relationship' is true.
#
# Our aim for this project is to find a more accurate measure for county's well-being, i.e. environment and economic factors may be considered, and how we can use this for a predictor model that can assist in assessing counties for their levels of crime. This project can be scaled for use in determining how the government can improve their allocation of resources to improve a county's well-being. However, because of bias in our project, our findings may only be applicable to counties similar to San Diego. That is, underrepresented counties should not be observed with our lens. Despite this bias, misuse or misinterpretation of our finding can be misleading and improperly measure a county's well-being. This can lead to reduction in select counties' aid from the government that can adversely affect them. Specifically when looking at funding for county police departments to combat crime or even funding for environmental initaitives to improve air quality in underepresented counties.
#
# After completing our exploratory data analysis for our project, we first observed that when it came to looking for emissions data for the top 10 rural counties in California, we couldn't find any. This further posits that there exists population biases. Perhaps these scarcely populated regions dont recieve enough funding to support on going data collection for vital information as environmental degradation. Additionally from our analyses when it came to the emissions data over the years for the top 10 most populated counties in California, we observed a donward trend further exemplyfying such population biases; as these densely populated cities may be getting funding and resources in order to combat emissions output.

# %% [markdown]
# # Discussion and Conclusion
#
# In our project, we investigated if there was a statistically significant relationship between a region’s economic health, environmental degradation, and unemployment rate on crime rates within California. Additionally, we looked at how we can use these variables to create a new standard measurement for economic health along the way. We hypothesized that there is a significant relationship between California’s economic health, environmental degradation, and unemployment rate on crime rates because all of these variables ultimately dictate a person’s quality of life. The environment can highly affect someone’s behavior to resort to crime as a last option to keep themselves afloat or alive if their quality of life or future is threatened.
#
# When it came to analysis overall we first highlight that we did not observe data for our top 10 rural counties in California while we did for Urban, this may come as a result of population biases between the two. Furthermore while we thought that we would observe more statisticallly significant results between our data specifically for GDP and Crime rates for both subsets of counties our data still proved to be useful in our analysis due to high condition numbers that we observed in our OLS results suggesting multicollinearity between many of our variables. Our big takeaways over all from our EDA were that AQI median proved to be a key indicator of envrionmental degradation for both rural and urban counties with repect to Property Crime rates and also that Unemployment rates and property crime rates are correlated which we further looked into in our QLEI model utlizing PCA for all variables of interest including the ones that had no significant results. Furthermore if time allowed we'd further expand our EDA by looking for more datasets in regards to greenhouse gas emmissions if they even exist, to further fix the missing data for rural counties in CA.
#
# In regards to the model, We see opposing correlations between urban and rural counties in comparing our new statistical measure, QLEI, to our baseline PCA model. Since PCA takes into account all variables as opposed to the chosen weighted variables of our index-based QLEI, it's possible that QLEI is penalizing things that PCA finds correlates with GDP, though in our EDA, we did not see this effect. More importantly, comparing QLEI and GDP yielded interesting results, finding that the disproportionate crime in high population density, high GDP counties could not rely on positive economic development alone to be penalized more by QLEI. While the two appear to slightly correlate, it's clear that controlling for factors that worsen quality of life for individuals shows a less equitable picture, particularly for urban counties. In the rural counties, however, population density and GDP did not result in such a clear-cut disparity, which may indicate more homogenized differences between rural counties. Regardless, we believe we've found enough to conclude that a data-driven economic measure is worth exploring further.
#
# Ultimately, while we were unable to find statistically significant links in most of the variables that we observed, the few items that did correlate not only aligned with our hypotheses on said data, but supported previous work we found in our research; observations of air quality and unemployment rates for crime rates lend credence to the idea that individual economic factors and climate have an effect on crime. Additionally, our ability to model this relationship for a new statistical measure is worth looking into further. While models like the Genuine Progress Indicator take into account other variables outside of Gross Domestic Product, both of these systems rely on simplistic formulas involving solely spending data. Involving statistical analyses in a myriad of categories beyond the scope of our original project, assigning weights to variables that could not otherwise be simplified by a dollar amount with accurate data could prove to be a more holistic approach to economic health that takes both pure economic output and individual needs into account.
#
#
# # Team Contributions
#
# Dean - Project Leader, Research, Economic Visualizations, Model
#
# Emily - Editing/Formatting, Drafting, Economic Visualizations
#
# Kevin - Ethics/Privacy, Analysis/Interpretations, Environmental Visualizations
#
# Richard - Merge Master, Data Wrangling, Environmental Visualizations, Slides
#
# Cedric - Data Wrangling, Environmental Visualizations, Slides
